# %%
import pandas as pd
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ObesityDataSet_raw_and_data_sinthetic.csv')
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='NObeyesdad', y='Weight', data=df)
plt.title('Obesity level v.s Weight', fontsize=17)
plt.ylabel('Weight (kg)', fontsize=12)
plt.xlabel('Obesity level', labelpad=20, fontsize=12)
# Out:
# Text(0.5, 0, 'Obesity level')

# %%
# fig, axes = plt.subplots(3)

alc_grouped = df.groupby('NObeyesdad')['CALC'].value_counts().unstack(fill_value=0)
alc_grouped.plot.bar()
plt.ylabel('Frequency')
plt.xlabel('Obesity level')
plt.title('Obesity level v.s Alcohol intake')
# Out:
# Text(0.5, 1.0, 'Obesity level v.s Alcohol intake')
